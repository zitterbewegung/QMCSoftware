# %% [markdown]
# <a href="https://colab.research.google.com/github/zitterbewegung/QMCSoftware/blob/patch-1/QMCSoftware.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zitterbewegung/QMCSoftware.git
# Out:
# Cloning into 'QMCSoftware'...
# remote: Enumerating objects: 16774, done.
# remote: Counting objects: 100% (1905/1905), done.
# remote: Compressing objects: 100% (636/636), done.
# remote: Total 16774 (delta 1311), reused 1784 (delta 1266), pack-reused 14869
# Receiving objects: 100% (16774/16774), 164.13 MiB | 23.03 MiB/s, done.
# Resolving deltas: 100% (11459/11459), done.

# %%
# %cd QMCSoftware
# !git checkout patch-1
# Out:
# /content/QMCSoftware
# Branch 'patch-1' set up to track remote branch 'patch-1' from 'origin'.
# Switched to a new branch 'patch-1'

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda create -n qmcpy python=3.7.0
# !conda activate qmcpy
# !conda install conda-build
# !conda develop .
# !pip install -r requirements/dev_colab.txt
# !pip install -e .
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:26
# 🔁 Restarting kernel...
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/qmcpy
#
#   added / updated specs:
#     - python=3.7.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
# ...

# %%
import qmcpy as qp
from numpy import pi, cos, sqrt, linalg
d = 2
dnb2 = qp.DigitalNetB2(d)
gauss_sobol = qp.Gaussian(dnb2, mean=0, covariance=1/2)
k = qp.CustomFun(
  true_measure = gauss_sobol, 
  g = lambda x: pi**(d/2)*cos(linalg.norm(x,axis=1)))
qmc_sobol_algorithm = qp.CubQMCSobolG(k, abs_tol=1e-3)
solution,data = qmc_sobol_algorithm.integrate()
print(data)
# Out:
# LDTransformData (AccumulateData Object)
#     solution        1.808
#     indv_error      7.67e-04
#     ci_low          1.807
#     ci_high         1.809
#     ci_comb_low     1.807
#     ci_comb_high    1.809
#     flags_comb      0
#     flags_indv      0
#     n_total         2^(12)
#     n               2^(12)
#     time_integrate  0.011
# CubQMCSobolG (StoppingCriterion Object)
#     abs_tol         0.001
#     rel_tol         0
#     n_init          2^(10)
#     n_max           2^(35)
# CustomFun (Integrand Object)
# Gaussian (TrueMeasure Object)
#     mean            0
#     covariance      2^(-1)
#     decomp_type     PCA
# DigitalNetB2 (DiscreteDistribution Object)
#     d               2^(1)
#     dvec            [0 1]
#     randomize       LMS_DS
#     graycode        0
#     entropy         183398336215623399779538069842872170582
#     spawn_key       ()

# %%
# %cd QMCSoftware
# Out:
# /content/QMCSoftware

# %%
# !conda install -c conda-forge libgfortran appnope
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - appnope
#     - libgfortran
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.3              |     pyhd8ed1ab_0           8 KB  conda-forge
#     libgfortran-3.0.0          |                1         281 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         289 KB
#
# The following NEW packages will be INSTALLED:
#
#   appnope            conda-forge/noarch::appnope-0.1.3-pyhd8ed1ab_0
#   libgfortran        conda-forge/linux-64::libgfortran-3.0.0-1
#
#
#
# ...
# appnope-0.1.3        | 8 KB      | : 100% 1.0/1 [00:00<00:00,  2.78it/s]
# libgfortran-3.0.0    | 281 KB    | : 100% 1.0/1 [00:00<00:00,  6.28it/s]
# done
# done
# done

# %%
# !pip install -e .
# Out:
# ERROR: File "setup.py" not found. Directory cannot be installed in editable mode: /content

# %%
# %cd /content/QMCSoftware
# !make tests
# Out:
# /content/QMCSoftware
#
# Doctests
# python -m coverage run --source=./ -m pytest --doctest-modules --disable-pytest-warnings qmcpy
# ============================= test session starts ==============================
# platform linux -- Python 3.7.10, pytest-5.4.3, py-1.10.0, pluggy-0.13.1
# rootdir: /content/QMCSoftware
# collected 33 items
#
# qmcpy/discrete_distribution/halton.py .                                  [  3%]
# qmcpy/discrete_distribution/iid_std_uniform.py .                         [  6%]
# qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py .           [  9%]
# qmcpy/discrete_distribution/digital_net_b2/sobol_scipy.py .              [ 12%]
# qmcpy/discrete_distribution/lattice/lattice.py .                         [ 15%]
# qmcpy/integrand/asian_option.py .                                        [ 18%]
# qmcpy/integrand/box_integral.py .                                        [ 21%]
# ...

# %%
# Out:
# make: *** No rule to make target 'tests'.  Stop.

# %%
# play wit
