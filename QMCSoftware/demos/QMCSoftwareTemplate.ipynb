# %% [markdown]
# <a href="https://colab.research.google.com/github/zitterbewegung/QMCSoftware/blob/patch-1/QMCSoftware/demos/QMCSoftwareTemplate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QMCSoftware
#
# This notebook allows you to use QMCSoftware on Google Colab.

# %%
# %%capture
# !git clone https://github.com/zitterbewegung/QMCSoftware.git
# %cd QMCSoftware
# !git checkout master
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda create -n qmcpy python=3.7.0
# !conda activate qmcpy
# !conda install conda-build
# !conda develop .
# !pip install -r requirements/dev_colab.txt
# !pip install -e .

# %% [markdown]
# As a demo of QMC we will approximate the expected value of the $d$ dimensional Keister integrand.

# %% [markdown]
# $g(X)=\pi^{d/2}\cos(\lVert X \rVert)$
# where $X \sim \mathcal{N}(\boldsymbol{0},\boldsymbol{I}/2)$.

# %% [markdown]
# Here as a demo we can choose a Sobol’ discrete distribution with a corresponding Sobol’ cubature stopping criterion to preform quasi-Monte Carlo integration.

# %%
import qmcpy as qp
from numpy import pi, cos, sqrt, linalg
d = 2
dnb2 = qp.DigitalNetB2(d)
gauss_sobol = qp.Gaussian(dnb2, mean=0, covariance=1/2)
k = qp.CustomFun(
  true_measure = gauss_sobol, 
  g = lambda x: pi**(d/2)*cos(linalg.norm(x,axis=1)))
qmc_sobol_algorithm = qp.CubQMCSobolG(k, abs_tol=1e-3)
solution,data = qmc_sobol_algorithm.integrate()
print(data)
# Out:
# LDTransformData (AccumulateData Object)
#     solution        1.809
#     indv_error      9.71e-04
#     ci_low          1.808
#     ci_high         1.810
#     ci_comb_low     1.808
#     ci_comb_high    1.810
#     flags_comb      0
#     flags_indv      0
#     n_total         2^(12)
#     n               2^(12)
#     time_integrate  0.015
# CubQMCSobolG (StoppingCriterion Object)
#     abs_tol         0.001
#     rel_tol         0
#     n_init          2^(10)
#     n_max           2^(35)
# CustomFun (Integrand Object)
# Gaussian (TrueMeasure Object)
#     mean            0
#     covariance      2^(-1)
#     decomp_type     PCA
# DigitalNetB2 (DiscreteDistribution Object)
#     d               2^(1)
#     dvec            [0 1]
#     randomize       LMS_DS
#     graycode        0
#     entropy         242721303679974242809190625714109922152
#     spawn_key       ()

# %%
# !make tests
# Out:
# /content/QMCSoftware
#
# Doctests
# python -m coverage run --source=./ -m pytest --doctest-modules --disable-pytest-warnings qmcpy
# ============================= test session starts ==============================
# platform linux -- Python 3.7.10, pytest-5.4.3, py-1.10.0, pluggy-0.13.1
# rootdir: /content/QMCSoftware
# collected 33 items
#
# qmcpy/discrete_distribution/halton.py .                                  [  3%]
# qmcpy/discrete_distribution/iid_std_uniform.py .                         [  6%]
# qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py .           [  9%]
# qmcpy/discrete_distribution/digital_net_b2/sobol_scipy.py .              [ 12%]
# qmcpy/discrete_distribution/lattice/lattice.py .                         [ 15%]
# qmcpy/integrand/asian_option.py .                                        [ 18%]
# qmcpy/integrand/box_integral.py .                                        [ 21%]
# qmcpy/integrand/custom_fun.py .                                          [ 24%]
# qmcpy/integrand/european_option.py .                                     [ 27%]
# qmcpy/integrand/ishigami.py .                                            [ 30%]
# qmcpy/integrand/keister.py .                                             [ 33%]
# qmcpy/integrand/linear0.py .                                             [ 36%]
# qmcpy/integrand/ml_call_options.py .                                     [ 39%]
# qmcpy/integrand/sobol_indices.py .                                       [ 42%]
# qmcpy/stopping_criterion/cub_mc_clt.py .                                 [ 45%]
# qmcpy/stopping_criterion/cub_mc_g.py .                                   [ 48%]
# qmcpy/stopping_criterion/cub_mc_ml.py .                                  [ 51%]
# qmcpy/stopping_criterion/cub_mc_ml_cont.py .                             [ 54%]
# qmcpy/stopping_criterion/cub_qmc_bayes_lattice_g.py .                    [ 57%]
# qmcpy/stopping_criterion/cub_qmc_bayes_net_g.py .                        [ 60%]
# qmcpy/stopping_criterion/cub_qmc_clt.py .                                [ 63%]
# qmcpy/stopping_criterion/cub_qmc_lattice_g.py .                          [ 66%]
# qmcpy/stopping_criterion/cub_qmc_ml.py .                                 [ 69%]
# qmcpy/stopping_criterion/cub_qmc_ml_cont.py .                            [ 72%]
# qmcpy/stopping_criterion/cub_qmc_net_g.py .                              [ 75%]
# qmcpy/true_measure/bernoulli_cont.py .                                   [ 78%]
# qmcpy/true_measure/brownian_motion.py .                                  [ 81%]
# qmcpy/true_measure/gaussian.py .                                         [ 84%]
# qmcpy/true_measure/johnsons_su.py .                                      [ 87%]
# qmcpy/true_measure/kumaraswamy.py .                                      [ 90%]
# qmcpy/true_measure/lebesgue.py .                                         [ 93%]
# qmcpy/true_measure/scipy_wrapper.py .                                    [ 96%]
# qmcpy/true_measure/uniform.py .                                          [100%]
#
# ============================= 33 passed in 11.20s ==============================
#
# Fastests
# python -W ignore -m coverage run --append --source=./ -m unittest discover -s test/fasttests/ 1>/dev/null
# ......................................................
# ----------------------------------------------------------------------
# Ran 54 tests in 33.813s
#
# OK
#
# Longtests
# python -W ignore -m coverage run --append --source=./ -m unittest discover -s test/longtests/ 1>/dev/null
# .................
# ----------------------------------------------------------------------
# Ran 17 tests in 23.394s
#
# OK
#
# Code coverage
# python -m coverage report -m
# Name                                                                       Stmts   Miss  Cover   Missing
# --------------------------------------------------------------------------------------------------------
# QMCSoftware/__init__.py                                                        0      0   100%
# QMCSoftware/qmcpy/__init__.py                                                  6      6     0%   1-7
# QMCSoftware/qmcpy/accumulate_data/__init__.py                                  7      7     0%   1-7
# QMCSoftware/qmcpy/accumulate_data/_accumulate_data.py                         15     15     0%   1-22
# QMCSoftware/qmcpy/accumulate_data/ld_transform_bayes_data.py                 213    213     0%   1-366
# QMCSoftware/qmcpy/accumulate_data/ld_transform_data.py                       107    107     0%   1-121
# QMCSoftware/qmcpy/accumulate_data/mean_var_data.py                            64     64     0%   1-87
# QMCSoftware/qmcpy/accumulate_data/mean_var_data_rep.py                        18     18     0%   1-25
# QMCSoftware/qmcpy/accumulate_data/mlmc_data.py                                68     68     0%   1-105
# QMCSoftware/qmcpy/accumulate_data/mlqmc_data.py                               79     79     0%   1-109
# QMCSoftware/qmcpy/discrete_distribution/__init__.py                            5      5     0%   1-5
# QMCSoftware/qmcpy/discrete_distribution/_discrete_distribution.py             48     48     0%   1-104
# QMCSoftware/qmcpy/discrete_distribution/c_lib/__init__.py                      1      1     0%   1
# QMCSoftware/qmcpy/discrete_distribution/c_lib/load_c_lib.py                    4      4     0%   1-5
# QMCSoftware/qmcpy/discrete_distribution/digital_net_b2/__init__.py             2      2     0%   1-2
# QMCSoftware/qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py     128    128     0%   1-298
# QMCSoftware/qmcpy/discrete_distribution/digital_net_b2/sobol_scipy.py         39     39     0%   1-103
# QMCSoftware/qmcpy/discrete_distribution/halton.py                             91     91     0%   1-173
# QMCSoftware/qmcpy/discrete_distribution/iid_std_uniform.py                    14     14     0%   1-49
# QMCSoftware/qmcpy/discrete_distribution/lattice/__init__.py                    1      1     0%   1
# QMCSoftware/qmcpy/discrete_distribution/lattice/lattice.py                   116    116     0%   1-245
# QMCSoftware/qmcpy/integrand/__init__.py                                       10     10     0%   1-10
# QMCSoftware/qmcpy/integrand/_integrand.py                                    121    121     0%   1-236
# QMCSoftware/qmcpy/integrand/asian_option.py                                   60     60     0%   1-138
# QMCSoftware/qmcpy/integrand/box_integral.py                                   21     21     0%   1-59
# QMCSoftware/qmcpy/integrand/custom_fun.py                                     14     14     0%   1-53
# QMCSoftware/qmcpy/integrand/european_option.py                                43     43     0%   1-99
# QMCSoftware/qmcpy/integrand/ishigami.py                                       41     41     0%   1-97
# QMCSoftware/qmcpy/integrand/keister.py                                        29     29     0%   1-77
# QMCSoftware/qmcpy/integrand/linear0.py                                        13     13     0%   1-34
# QMCSoftware/qmcpy/integrand/ml_call_options.py                               120    120     0%   1-229
# QMCSoftware/qmcpy/integrand/sobol_indices.py                                  76     76     0%   1-173
# QMCSoftware/qmcpy/stopping_criterion/__init__.py                              12     12     0%   1-12
# QMCSoftware/qmcpy/stopping_criterion/_cub_bayes_ld_g.py                      125    125     0%   1-198
# QMCSoftware/qmcpy/stopping_criterion/_cub_qmc_ld_g.py                        118    118     0%   1-161
# QMCSoftware/qmcpy/stopping_criterion/_stopping_criterion.py                   26     26     0%   1-54
# QMCSoftware/qmcpy/stopping_criterion/cub_mc_clt.py                            54     54     0%   1-154
# QMCSoftware/qmcpy/stopping_criterion/cub_mc_g.py                             107    107     0%   1-249
# QMCSoftware/qmcpy/stopping_criterion/cub_mc_ml.py                             71     71     0%   1-183
# QMCSoftware/qmcpy/stopping_criterion/cub_mc_ml_cont.py                        97     97     0%   1-230
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_bayes_lattice_g.py               89     89     0%   1-224
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_bayes_net_g.py                   93     93     0%   1-249
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_clt.py                           97     97     0%   1-283
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_lattice_g.py                     13     13     0%   1-165
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_ml.py                            53     53     0%   1-147
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_ml_cont.py                       86     86     0%   1-209
# QMCSoftware/qmcpy/stopping_criterion/cub_qmc_net_g.py                         12     12     0%   1-222
# QMCSoftware/qmcpy/true_measure/__init__.py                                     9      9     0%   1-9
# QMCSoftware/qmcpy/true_measure/_true_measure.py                               76     76     0%   1-170
# QMCSoftware/qmcpy/true_measure/bernoulli_cont.py                              36     36     0%   1-65
# QMCSoftware/qmcpy/true_measure/brownian_motion.py                             21     21     0%   1-56
# QMCSoftware/qmcpy/true_measure/gaussian.py                                    52     52     0%   1-96
# QMCSoftware/qmcpy/true_measure/johnsons_su.py                                 50     50     0%   1-88
# QMCSoftware/qmcpy/true_measure/kumaraswamy.py                                 36     36     0%   1-68
# QMCSoftware/qmcpy/true_measure/lebesgue.py                                    20     20     0%   1-42
# QMCSoftware/qmcpy/true_measure/scipy_wrapper.py                               43     43     0%   1-88
# QMCSoftware/qmcpy/true_measure/uniform.py                                     39     39     0%   1-70
# QMCSoftware/qmcpy/util/__init__.py                                             4      4     0%   1-4
# QMCSoftware/qmcpy/util/abstraction_functions.py                               41     41     0%   3-65
# QMCSoftware/qmcpy/util/exceptions_warnings.py                                 17     17     0%   2-71
# QMCSoftware/qmcpy/util/latnetbuilder_linker.py                                39     39     0%   1-59
# QMCSoftware/qmcpy/util/math_functions.py                                       6      6     0%   3-23
# QMCSoftware/setup.py                                                          31     31     0%   1-54
# QMCSoftware/test/__init__.py                                                   0      0   100%
# QMCSoftware/workouts/__init__.py                                               4      4     0%   1-4
# QMCSoftware/workouts/integration_examples/__init__.py                          4      4     0%   1-4
# QMCSoftware/workouts/integration_examples/asian_option_multi_level.py          9      9     0%   6-33
# QMCSoftware/workouts/integration_examples/asian_option_single_level.py        58     58     0%   6-97
# QMCSoftware/workouts/integration_examples/keister.py                          36     36     0%   6-58
# QMCSoftware/workouts/integration_examples/pi_problem.py                       34     34     0%   6-50
# QMCSoftware/workouts/lds_sequences/__init__.py                                 1      1     0%   1
# QMCSoftware/workouts/lds_sequences/python_sequences.py                        28     28     0%   3-47
# QMCSoftware/workouts/mc_vs_qmc/__init__.py                                     5      5     0%   1-5
# QMCSoftware/workouts/mc_vs_qmc/importance_sampling.py                         26     26     0%   3-36
# QMCSoftware/workouts/mc_vs_qmc/integrations_asian_call.py                     34     34     0%   3-45
# QMCSoftware/workouts/mc_vs_qmc/integrations_keister.py                        34     34     0%   3-46
# QMCSoftware/workouts/mc_vs_qmc/vary_abs_tol.py                                31     31     0%   6-44
# QMCSoftware/workouts/mc_vs_qmc/vary_dimension.py                              28     28     0%   6-41
# QMCSoftware/workouts/mlmc/__init__.py                                          2      2     0%   1-2
# QMCSoftware/workouts/mlmc/european_option.py                                  42     42     0%   3-56
# QMCSoftware/workouts/mlmc/mcqmc06.py                                          11     11     0%   3-27
# QMCSoftware/workouts/mlmc/mlmc_test.py                                        79     79     0%   3-126
# __init__.py                                                                    0      0   100%
# qmcpy/__init__.py                                                              6      0   100%
# qmcpy/accumulate_data/__init__.py                                              7      0   100%
# qmcpy/accumulate_data/_accumulate_data.py                                     15      1    93%   15
# qmcpy/accumulate_data/ld_transform_bayes_data.py                             213     55    74%   52, 91, 100, 123-134, 140-146, 149-157, 163, 169, 178, 201-210, 217-218, 226-230, 251-255, 268, 274, 289-292, 303-304, 323, 358, 361-366
# qmcpy/accumulate_data/ld_transform_data.py                                   107      5    95%   64-68
# qmcpy/accumulate_data/mean_var_data.py                                        64      5    92%   33, 35, 37, 40, 50
# qmcpy/accumulate_data/mean_var_data_rep.py                                    18      0   100%
# qmcpy/accumulate_data/mlmc_data.py                                            68      0   100%
# qmcpy/accumulate_data/mlqmc_data.py                                           79     11    86%   98-109
# qmcpy/discrete_distribution/__init__.py                                        5      0   100%
# qmcpy/discrete_distribution/_discrete_distribution.py                         48     13    73%   19, 21, 25, 33, 49, 53, 74, 89, 95-104
# qmcpy/discrete_distribution/c_lib/__init__.py                                  1      0   100%
# qmcpy/discrete_distribution/c_lib/load_c_lib.py                                4      0   100%
# qmcpy/discrete_distribution/digital_net_b2/__init__.py                         2      0   100%
# qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py                 128     20    84%   124-125, 137-138, 143-149, 155, 164-167, 174-182, 192, 215-219, 267, 273
# qmcpy/discrete_distribution/digital_net_b2/sobol_scipy.py                     39      5    87%   57-58, 61, 88, 103
# qmcpy/discrete_distribution/halton.py                                         91      4    96%   87, 92, 158, 161
# qmcpy/discrete_distribution/iid_std_uniform.py                                14      0   100%
# qmcpy/discrete_distribution/lattice/__init__.py                                1      0   100%
# qmcpy/discrete_distribution/lattice/lattice.py                               116     10    91%   103, 107, 114-117, 122, 145, 225, 227, 229
# qmcpy/integrand/__init__.py                                                   10      0   100%
# qmcpy/integrand/_integrand.py                                                121     13    89%   28, 30, 32, 43, 60, 84, 110, 136-138, 204, 219, 240
# qmcpy/integrand/asian_option.py                                               60      4    93%   66, 69, 118, 125
# qmcpy/integrand/box_integral.py                                               21      0   100%
# qmcpy/integrand/custom_fun.py                                                 14      0   100%
# qmcpy/integrand/european_option.py                                            43      2    95%   58, 67
# qmcpy/integrand/ishigami.py                                                   41     11    73%   40, 51, 81-97
# qmcpy/integrand/keister.py                                                    29      0   100%
# qmcpy/integrand/linear0.py                                                    13      0   100%
# qmcpy/integrand/ml_call_options.py                                           120     11    91%   61, 86-96
# qmcpy/integrand/sobol_indices.py                                              76      3    96%   106, 149-150
# qmcpy/stopping_criterion/__init__.py                                          12      0   100%
# qmcpy/stopping_criterion/_cub_bayes_ld_g.py                                  125     18    86%   24-30, 93, 98, 171-198
# qmcpy/stopping_criterion/_cub_qmc_ld_g.py                                    118      9    92%   26-32, 53, 56, 102, 160-161
# qmcpy/stopping_criterion/_stopping_criterion.py                               26      7    73%   20, 23, 26, 31, 33, 47, 51
# qmcpy/stopping_criterion/cub_mc_clt.py                                        54      2    96%   153-154
# qmcpy/stopping_criterion/cub_mc_g.py                                         107     15    86%   159-169, 180-187, 248-249
# qmcpy/stopping_criterion/cub_mc_ml.py                                         71      8    89%   90, 92, 94, 150, 180-183
# qmcpy/stopping_criterion/cub_mc_ml_cont.py                                    97     13    87%   88, 90, 92, 95, 155-162, 172-175, 201-204
# qmcpy/stopping_criterion/cub_qmc_bayes_lattice_g.py                           89     37    58%   108, 110, 129-155, 188, 192-194, 212-222
# qmcpy/stopping_criterion/cub_qmc_bayes_net_g.py                               93     25    73%   113, 155-165, 174-176, 180-182, 186-188, 197-204, 243
# qmcpy/stopping_criterion/cub_qmc_clt.py                                       97      6    94%   171-173, 196, 282-283
# qmcpy/stopping_criterion/cub_qmc_lattice_g.py                                 13      2    85%   163, 165
# qmcpy/stopping_criterion/cub_qmc_ml.py                                        53      6    89%   81, 113, 144-147
# qmcpy/stopping_criterion/cub_qmc_ml_cont.py                                   86     11    87%   92, 143-151, 160-163, 181-184
# qmcpy/stopping_criterion/cub_qmc_net_g.py                                     12      1    92%   219
# qmcpy/true_measure/__init__.py                                                 9      0   100%
# qmcpy/true_measure/_true_measure.py                                           76     13    83%   12, 14, 16, 26-28, 38-40, 69, 86, 103, 126, 147, 167
# qmcpy/true_measure/bernoulli_cont.py                                          36      2    94%   39, 61
# qmcpy/true_measure/brownian_motion.py                                         21      0   100%
# qmcpy/true_measure/gaussian.py                                                52      4    92%   60, 62, 72, 89
# qmcpy/true_measure/johnsons_su.py                                             50      3    94%   58, 60, 81
# qmcpy/true_measure/kumaraswamy.py                                             36      3    92%   45, 47, 63
# qmcpy/true_measure/lebesgue.py                                                20      1    95%   32
# qmcpy/true_measure/scipy_wrapper.py                                           43      2    95%   57, 82
# qmcpy/true_measure/uniform.py                                                 39      2    95%   43, 65
# qmcpy/util/__init__.py                                                         4      0   100%
# qmcpy/util/abstraction_functions.py                                           41      2    95%   38, 44
# qmcpy/util/exceptions_warnings.py                                             17      3    82%   6, 42-44
# qmcpy/util/latnetbuilder_linker.py                                            39     36     8%   23-59
# qmcpy/util/math_functions.py                                                   6      1    83%   20
# setup.py                                                                      31     31     0%   1-54
# test/__init__.py                                                               0      0   100%
# test/fasttests/test_discrete_distribs.py                                     104      2    98%   17, 170
# test/fasttests/test_integrands.py                                             41      1    98%   65
# test/fasttests/test_stopping_criteria.py                                     214      1    99%   281
# test/fasttests/test_true_measures.py                                          37      1    97%   71
# test/longtests/test_integrate.py                                             110      1    99%   184
# test/longtests/test_workouts.py                                               23      1    96%   31
# workouts/__init__.py                                                           4      0   100%
# workouts/integration_examples/__init__.py                                      4      0   100%
# workouts/integration_examples/asian_option_multi_level.py                      9      1    89%   33
# workouts/integration_examples/asian_option_single_level.py                    58      2    97%   96-97
# workouts/integration_examples/keister.py                                      36      1    97%   58
# workouts/integration_examples/pi_problem.py                                   34     12    65%   22-30, 44-48
# workouts/lds_sequences/__init__.py                                             1      0   100%
# workouts/lds_sequences/python_sequences.py                                    28      3    89%   45-47
# workouts/mc_vs_qmc/__init__.py                                                 5      0   100%
# workouts/mc_vs_qmc/importance_sampling.py                                     26      2    92%   31-36
# workouts/mc_vs_qmc/integrations_asian_call.py                                 34      6    82%   36-38, 41-43
# workouts/mc_vs_qmc/integrations_keister.py                                    34      6    82%   36-38, 41-43
# workouts/mc_vs_qmc/vary_abs_tol.py                                            31      3    90%   39, 43-44
# workouts/mc_vs_qmc/vary_dimension.py                                          28      2    93%   40-41
# workouts/mlmc/__init__.py                                                      2      0   100%
# workouts/mlmc/european_option.py                                              42      1    98%   56
# workouts/mlmc/mcqmc06.py                                                      11      1    91%   27
# workouts/mlmc/mlmc_test.py                                                    79      7    91%   80-83, 85-87
# --------------------------------------------------------------------------------------------------------
# TOTAL                                                                       7755   4103    47%

# %%
|
